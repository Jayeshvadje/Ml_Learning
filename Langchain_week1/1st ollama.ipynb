# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from langchain_ollama import OllamaLLM
#       2 ollama =OllamaLLM(base_urls = "http://localhost:11434",
#       3                model="mario")
# ----> 4 print(ollama("who are you ?"))
#
# TypeError: 'OllamaLLM' object is not callable

# %%
from langchain_ollama import OllamaLLM


ollama = OllamaLLM(
    base_url="http://localhost:11434",
    model="mario"
)

# 3. Use .invoke() with a quoted string prompt
response = ollama.invoke("who are you?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[3], line 10
#       4 ollama = OllamaLLM(
#       5     base_url="http://localhost:11434",
#       6     model="mario"
#       7 )
#       9 # 3. Use .invoke() with a quoted string prompt
# ---> 10 response = ollama.invoke("who are you?")
#      11 print(response)
#
# File ~\PycharmProjects\ML_Learning\.venv\Lib\site-packages\langchain_core\language_models\llms.py:381, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     370 @override
#     371 def invoke(
#     372     self,
#    (...)    377     **kwargs: Any,
#     378 ) -> str:
#     379     config = ensure_config(config)
#     380     return (
# --> 381         self.generate_prompt(
#     382             [self._convert_input(input)],
#     383             stop=stop,
#     384             callbacks=config.get("callbacks"),
#     385             tags=config.get("tags"),
#     386             metadata=config.get("metadata"),
#     387             run_name=config.get("run_name"),
#     388             run_id=config.pop("run_id", None),
#     389             **kwargs,
#     390         )
#     391         .generations[0][0]
#     392         .text
#     393     )
#
# File ~\PycharmProjects\ML_Learning\.venv\Lib\site-packages\langchain_core\language_models\llms.py:798, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     789 @override
#     790 def generate_prompt(
#     791     self,
#    (...)    795     **kwargs: Any,
#     796 ) -> LLMResult:
#     797     prompt_strings = [p.to_string() for p in prompts]
# --> 798     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\PycharmProjects\ML_Learning\.venv\Lib\site-packages\langchain_core\language_models\llms.py:1028, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1009 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#    1010     run_managers = [
#    1011         callback_manager.on_llm_start(
#    1012             self._serialized,
#    (...)   1026         )
#    1027     ]
# -> 1028     return self._generate_helper(
#    1029         prompts,
#    1030         stop,
#    1031         run_managers,
#    1032         new_arg_supported=bool(new_arg_supported),
#    1033         **kwargs,
#    1034     )
#    1035 if len(missing_prompts) > 0:
#    1036     run_managers = [
#    1037         callback_managers[idx].on_llm_start(
#    1038             self._serialized,
#    (...)   1045         for idx in missing_prompt_idxs
#    1046     ]
#
# File ~\PycharmProjects\ML_Learning\.venv\Lib\site-packages\langchain_core\language_models\llms.py:824, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     813 def _generate_helper(
#     814     self,
#     815     prompts: list[str],
#    (...)    820     **kwargs: Any,
#     821 ) -> LLMResult:
#     822     try:
#     823         output = (
# --> 824             self._generate(
#     825                 prompts,
#     826                 stop=stop,
#     827                 # TODO: support multiple run managers
#     828                 run_manager=run_managers[0] if run_managers else None,
#     829                 **kwargs,
#     830             )
#     831             if new_arg_supported
#     832             else self._generate(prompts, stop=stop)
#     833         )
#     834     except BaseException as e:
#     835         for run_manager in run_managers:
#
# File ~\PycharmProjects\ML_Learning\.venv\Lib\site-packages\langchain_ollama\llms.py:470, in OllamaLLM._generate(self, prompts, stop, run_manager, **kwargs)
#     468 generations = []
#     469 for prompt in prompts:
# --> 470     final_chunk = self._stream_with_aggregation(
#     471         prompt,
#     472         stop=stop,
#     473         run_manager=run_manager,
#     474         verbose=self.verbose,
#     475         **kwargs,
#     476     )
#     477     generations.append([final_chunk])
#     478 return LLMResult(generations=generations)
#
# File ~\PycharmProjects\ML_Learning\.venv\Lib\site-packages\langchain_ollama\llms.py:429, in OllamaLLM._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     427 final_chunk = None
#     428 thinking_content = ""
# --> 429 for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     430     if not isinstance(stream_resp, str):
#     431         if stream_resp.get("thinking"):
#
# File ~\PycharmProjects\ML_Learning\.venv\Lib\site-packages\langchain_ollama\llms.py:373, in OllamaLLM._create_generate_stream(self, prompt, stop, **kwargs)
#     368     msg = (
#     369         "Ollama sync client is not initialized. "
#     370         "Make sure the model was properly constructed."
#     371     )
#     372     raise RuntimeError(msg)
# --> 373 yield from self._client.generate(
#     374     **self._generate_params(prompt, stop=stop, **kwargs)
#     375 )
#
# File ~\PycharmProjects\ML_Learning\.venv\Lib\site-packages\ollama\_client.py:189, in Client._request.<locals>.inner()
#     187 except httpx.HTTPStatusError as e:
#     188   e.response.read()
# --> 189   raise ResponseError(e.response.text, e.response.status_code) from None
#     191 for line in r.iter_lines():
#     192   part = json.loads(line)
#
# ResponseError: model requires more system memory (2.5 GiB) than is available (1.9 GiB) (status code: 500)
