# %%
import pandas as pd
import numpy as np

prices = pd.Series([23,34,12,34],name ="price")
print("target vector (y):")
prices
# Out:
# target vector (y):
# 0    23
# 1    34
# 2    12
# 3    34
# Name: price, dtype: int64

# %%
data={"size" : [1500,1000,1800,3400],
      "bedroom":[2,1,3,4],
      "year_build" : [2023,2025,2021,2026]}
df=pd.DataFrame(data)
df
# Out:
#    size  bedroom  year_build
# 0  1500        2        2023
# 1  1000        1        2025
# 2  1800        3        2021
# 3  3400        4        2026

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['size', 'bedroom', 'year_build'], dtype='str')

# %%
df.isnull()
# Out:
#     size  bedroom  year_build
# 0  False    False       False
# 1  False    False       False
# 2  False    False       False
# 3  False    False       False

# %%
df.describe()
# Out:
#               size   bedroom   year_build
# count     4.000000  4.000000     4.000000
# mean   1925.000000  2.500000  2023.750000
# std    1037.223859  1.290994     2.217356
# min    1000.000000  1.000000  2021.000000
# 25%    1375.000000  1.750000  2022.500000
# 50%    1650.000000  2.500000  2024.000000
# 75%    2200.000000  3.250000  2025.250000
# max    3400.000000  4.000000  2026.000000

# %%
df.dtypes
# Out:
# size          int64
# bedroom       int64
# year_build    int64
# dtype: object

# %%
df[["size","bedroom"]]
# Out:
#    size  bedroom
# 0  1500        2
# 1  1000        1
# 2  1800        3
# 3  3400        4

# %%
X=pd.DataFrame({"Age":[23,43,25,54],
"cholestrol" : [234,235,342,45],
"BP":[23,4,32,23]})

# %%
Y=pd.Series([1,0,1,1],name="risk_level")
Y
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# Name: risk_level, dtype: int64

# %%
X.shape
# Out:
# (4, 3)

# %%
X.head()
# Out:
#    Age  cholestrol  BP
# 0   23         234  23
# 1   43         235   4
# 2   25         342  32
# 3   54          45  23

# %%
len(Y)
# Out:
# 4

# %%
df=pd.read_csv("titanic.csv")
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.shape
# Out:
# (891, 12)

# %%
df[["PassengerId","Survived"]].head()
# Out:
#    PassengerId  Survived
# 0            1         0
# 1            2         1
# 2            3         1
# 3            4         1
# 4            5         0

# %%
df["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df.iloc[0:800,:]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 795          796         0       2
# 796          797         1       1
# 797          798         1       3
# 798          799         0       3
# 799          800         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[800:,:]
# Out:
#      PassengerId  Survived  Pclass  \
# 800          801         0       2
# 801          802         1       2
# 802          803         1       1
# 803          804         1       3
# 804          805         1       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                             Name     Sex    Age  SibSp  Parch  \
# 800                         Ponesell, Mr. Martin    male  34.00      0      0
# 801  Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.00      1      1
# 802          Carter, Master. William Thornton II    male  11.00      1      2
# 803              Thomas, Master. Assad Alexander    male   0.42      0      1
# 804                      Hedman, Mr. Oskar Arvid    male  27.00      0      0
# ...

# %%
df.loc[0:10,["Age","Sex"]]
# Out:
#      Age     Sex
# 0   22.0    male
# 1   38.0  female
# 2   26.0  female
# 3   35.0  female
# 4   35.0    male
# 5    NaN    male
# 6   54.0    male
# 7    2.0    male
# 8   27.0  female
# 9   14.0  female
# 10   4.0  female

# %%
a=df[(df["Age"]>70) & (df["Sex"]=="female")]
a
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df["Age"]>70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
df[df["Cabin"].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df=df.dropna(subset=["Cabin"])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Cabin"]=df["Cabin"].fillna(df["Cabin"].mode())

# %%
df[df["Cabin"].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df= df.dropna(subset=["Cabin"])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(columns=["Cabin"])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Fare"]=df["Fare"].clip(upper=60)

# %%
df["Fare"]
# Out:
# 1      60.0000
# 3      53.1000
# 6      51.8625
# 10     16.7000
# 11     26.5500
#         ...
# 871    52.5542
# 872     5.0000
# 879    60.0000
# 887    30.0000
# 889    30.0000
# Name: Fare, Length: 204, dtype: float64

# %%
df['Fare'] = df["Fare"].astype(int)

# %%
df['Fare']
# Out:
# 1      60
# 3      53
# 6      51
# 10     16
# 11     26
#        ..
# 871    52
# 872     5
# 879    60
# 887    30
# 889    30
# Name: Fare, Length: 204, dtype: int64

# %%
df.sort_values(by="Fare",ascending=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 263          264         0       1
# 815          816         0       1
# 806          807         0       1
# 872          873         0       1
# 699          700         0       3
# ..           ...       ...     ...
# 759          760         1       1
# 742          743         1       1
# 849          850         1       1
# 835          836         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 263                              Harrison, Mr. William    male  40.0      0
# 815                                   Fry, Mr. Richard    male   NaN      0
# 806                             Andrews, Mr. Thomas Jr    male  39.0      0
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 699           Humblen, Mr. Adolf Mathias Nicolai Olsen    male  42.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_index()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby("Pclass")["Survived"].sum()
# Out:
# Pclass
# 1    117
# 2     13
# 3      6
# Name: Survived, dtype: int64

# %%
df.groupby("Sex").agg({'Age': 'mean',
    'Fare': 'max'})
# Out:
#               Age  Fare
# Sex
# female  33.061111    60
# male    38.451789    60

# %%
print( df[["Survived","Pclass"]].corr())
# Out:
#           Survived    Pclass
# Survived  1.000000 -0.033032
# Pclass   -0.033032  1.000000

# %%
df["Fare"].max()
# Out:
# np.int64(60)

# %%
df["Fare"].mean()
# Out:
# np.float64(44.51960784313726)
