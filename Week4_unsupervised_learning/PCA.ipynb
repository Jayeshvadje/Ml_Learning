# %% [markdown]
# PCA is a principle component analysis which helps in the dimensionality reduction while retaining as much variability as possbible in data
#
# high dimensionality data can be noisy <br>
# many features are correlated to each other <br>
# visualization of data is hard beyond 3d

# %% [markdown]
# Interview questions for PCA
#
# What is PCA and why is it used?
#
# What problem does PCA solve?
#
# What is dimensionality reduction?
#
# How does PCA work step by step?
#
# What are principal components?
#
# What is the first principal component?
#
# What is the difference between PCA and feature selection?
#
# Why do we standardize data before PCA?
#
# What is explained variance ratio?
#
# How do you choose the number of principal components?
#
# What is the scree plot?
#
# What are eigenvalues and eigenvectors in PCA?
#
# What is the role of covariance matrix in PCA?
#
# What are the advantages of PCA?
#
# What are the limitations of PCA?
#
# When should PCA be used?
#
# When should PCA be avoided?
#
# What is the difference between PCA and LDA?
#
# How is PCA useful in clustering or classification?
#
# Can PCA handle non-linear data?
#
# Why is PCA considered a feature extraction method?
#
# Why is PCA sensitive to feature scaling?
#
# Why does PCA reduce interpretability?
#
# What happens if you keep too few components?
#
# What happens if you keep too many components?
#
# Why is PCA useful for noisy or high-dimensional data?
#
# How is PCA related to multicollinearity?
#
# Why is PCA often used before k-NN or clustering?
#
# Why do we scale data before PCA?
