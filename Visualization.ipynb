# %%
from itertools import groupby

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.histplot(df["Age"],kde=True,color="blue")
plt.title("Histogram of Age")
plt.show()

# %%
sns.boxplot(x=df["Fare"])
plt.show()

# %%
df["Fare"].plot(kind="box")
# Out:
# <Axes: >

# %%
df["Age"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind="scatter",x="Fare",y="Age",color="blue")
# Out:
# <Axes: xlabel='Fare', ylabel='Age'>

# %%
df.plot(kind="scatter",y="Fare",x="Pclass",color="red")
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
df.groupby("Pclass")["Survived"].mean().plot(kind="bar",color=["red","blue","green"])
# Out:
# <Axes: xlabel='Pclass'>

# %%
df.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
df["Age"].plot(kind="line")
# Out:
# <Axes: >

# %%
sns.histplot(df['Age'], bins=20, color='red')
plt.show()

# %%
sns.histplot(df['Age'],bins=20, color='red')
plt.title("Histogram of Age",fontsize=10,fontweight='bold')
plt.xlabel("Age")
plt.ylabel("Numebr of passengers")
plt.grid(True,linestyle='--',alpha=0.9)
plt.show()
plt.show()

# %%
# Using 'hue' automatically generates a legend in Seaborn
sns.scatterplot(data=df, x='Age', y='Fare', hue='Survived', palette='viridis')

# 5. Legend Customization
plt.legend(title='Status', labels=['Perished', 'Survived'], loc='upper right')

# %%
plt.figure(figsize=(12, 6))
sns.set_theme(style="darkgrid")

# Plotting
sns.boxplot(data=df, x='Pclass', y='Age', hue='Sex')

# Customization
plt.title('Age Distribution by Class and Gender', fontsize=15)
plt.xlabel('Passenger Class')
plt.ylabel('Age')
plt.xticks([0, 1, 2], ['1st Class', '2nd Class', '3rd Class']) # Rename ticks
plt.grid(axis='y', alpha=0.3)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(12, 5))
sns.set_theme(style="ticks")
sns.boxplot(data=df,x="Pclass",y="Fare",hue="Sex")
plt.title("Fare discribution by class",fontstyle="italic",fontsize=15)
plt.xlabel("passenger class")
plt.ylabel("Fare of passenger")
plt.xticks([0,1,2],["1st Class","2nd Class","3rd Class"])
plt.grid(axis="y",alpha=0.6)
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.set_theme(style="darkgrid")
plt.title("Performance Test Results")
# Out:
# Text(0.5, 1.0, 'Performance Test Results')

# %%
sns.countplot(data=df, x='Pclass', palette='Paired')
plt.legend(title='Test Result', loc='upper left')
plt.show()
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_16744\3824463485.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Pclass', palette='Paired')
# C:\Users\priya\AppData\Local\Temp\ipykernel_16744\3824463485.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Test Result', loc='upper left')

# %%
# Create a layout with 1 row and 2 columns
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plot 1 on the left
sns.histplot(df['Fare'], ax=axes[0])
axes[0].set_title("Distribution")

# Plot 2 on the right
sns.boxplot(y=df['Fare'], ax=axes[1])
axes[1].set_title("Outliers")
# Out:
# Text(0.5, 1.0, 'Outliers')

# %%
# Interactive survival count by class
import plotly.express as px
fig = px.bar(df, x="Pclass", y="Survived", color="Sex",
             title="Titanic Survival by Class and Gender",
             barmode="group") # Use "group" for side-by-side bars

# %%
fig

# %%
import cufflinks as cf
cf.go_offline()
df["Age"].iplot(kind="scatter")
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 3
#       1 import cufflinks as cf
#       2 cf.go_offline()
# ----> 3 df["Age"].iplot(kind="scatter")
#
# ...

# %%
import cufflinks as cf
cf.go_offline() # Necessary to run Plotly locally in your notebook

# The simplest interactive plot ever:
df["Age"].iplot(kind='hist', color='rgb(255, 153, 51)')
# Cast to native Python float

# %%
import cufflinks as cf
cf.getThemes() # See available: 'pearl', 'solar', 'space', 'ggplot'
df.iplot(kind='hist', theme='pearl')

# %%
import nbformat
import plotly.io as pio
pio.renderers.default = "browser"
print(f"nbformat version: {nbformat.__version__}")
fig=px.bar(df,x="Pclass",y="Survived",color="Sex")
fig.show()

# %%
df["Age"].plot(kind="hist",color='green')

# %%
sns.scatterplot(data=df,x="Pclass",y="Age")
plt.show()

# %%
px.bar(df,x="Pclass",y="Survived",color="Sex")

# %%
import pandas as pd
import numpy as np

data = {
    'Test_Name': [f'TC_{i}' for i in range(1, 21)],
    'Status': np.random.choice(['Pass', 'Fail', 'Flaky'], 20, p=[0.7, 0.2, 0.1]),
    'Response_Time': np.random.uniform(0.5, 5.0, 20),
    'Module': np.random.choice(['Login', 'Payments', 'Search'], 20)
}
df = pd.DataFrame(data)

# %%
df
# Out:
#    Test_Name Status  Response_Time    Module
# 0       TC_1  Flaky       2.767164    Search
# 1       TC_2   Pass       3.148763     Login
# 2       TC_3   Fail       0.565236  Payments
# 3       TC_4   Pass       2.929669    Search
# 4       TC_5  Flaky       4.763157  Payments
# 5       TC_6   Pass       2.126084    Search
# 6       TC_7   Pass       0.974278  Payments
# 7       TC_8   Pass       3.012664     Login
# 8       TC_9   Pass       3.142608  Payments
# 9      TC_10   Pass       4.318018     Login
# 10     TC_11   Pass       0.881986     Login
# 11     TC_12  Flaky       1.369297     Login
# 12     TC_13   Pass       1.279987     Login
# 13     TC_14   Pass       4.781659     Login
# 14     TC_15   Pass       0.981296     Login
# 15     TC_16   Pass       3.852817  Payments
# 16     TC_17   Pass       2.312620  Payments
# 17     TC_18   Fail       0.745832  Payments
# 18     TC_19  Flaky       3.769112     Login
# 19     TC_20   Fail       3.923426     Login

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.countplot(data=df,x="Status",palette={"Pass" : "green", "Fail" : "red", "Flaky" : "orange"},hue="Status",legend="brief")

plt.title("Distribution of Status")
plt.xlabel("Status")
plt.ylabel("Total Count")
plt.show()

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x="Module",y="Response_Time")
plt.title("Distribution of Response Time")
plt.xlabel("Module")
plt.ylabel("Time")
plt.show()

# %%
a=px.scatter(df,x="Test_Name",y="Response_Time",color="Status",width=800,height=400)
a.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
