# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Using the California Housing data or Titanic
# This instantly shows you the relationship between every pair of features
sns.pairplot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2 import matplotlib.pyplot as plt
#       4 # Using the California Housing data or Titanic
#       5 # This instantly shows you the relationship between every pair of features
# ----> 6 sns.pairplot()
#       7 plt.show()
#
# TypeError: pairplot() missing 1 required positional argument: 'data'
